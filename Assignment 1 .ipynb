# %%
student_list = [ "Amit" , "Rahul" , "Priya" , "Sneha" ]
print("\nStudent List:")
print(student_list)
# Out:
# Student List:
# ['Amit', 'Rahul', 'Priya', 'Sneha']

# %%
student_tuple = ( "Amit" , "Rahul" , "Priya" , "Sneha" )
print("\nStudent Tuple:")
print(student_tuple)
# Out:
# Student Tuple:
# ('Amit', 'Rahul', 'Priya', 'Sneha')

# %%
student_dict = {
    1:"Amit" , 
    2:"Rahul", 
    3:"Priya",
    4:"Sneha",
}
print("\nStudent Dict")
print(student_dict)
# Out:
# Student Dict
# {1: 'Amit', 2: 'Rahul', 3: 'Priya', 4: 'Sneha'}

# %%
student_dict = {
    1:"Amit" , 
    2:"Rahul", 
    3:"Priya",
    4:"Sneha",
}
print("\nStudent Dict")
print(student_dict)
student_dict[3] = "Preksha"
print("\After Updating:")
print(student_dict)
# Out:
# Student Dict
# {1: 'Amit', 2: 'Rahul', 3: 'Priya', 4: 'Sneha'}
# \After Updating:
# {1: 'Amit', 2: 'Rahul', 3: 'Preksha', 4: 'Sneha'}

# %%
student_dict = {
    1:"Amit" , 
    2:"Rahul", 
    3:"Priya",
    4:"Sneha",
}
print("\nStudent Dict")
print(student_dict)
student_dict[5] = "Preksha"
print("\nAfter Adding")
print(student_dict)
# Out:
# Student Dict
# {1: 'Amit', 2: 'Rahul', 3: 'Priya', 4: 'Sneha'}
#
# After Adding
# {1: 'Amit', 2: 'Rahul', 3: 'Priya', 4: 'Sneha', 5: 'Preksha'}

# %%
student_dict = {
    1:"Amit" , 
    2:"Rahul", 
    3:"Priya",
    4:"Sneha",
}
print("\nStudent Dict")
print(student_dict)
del student_dict[2]
print("\nAfter Deleting")
print(student_dict)
# Out:
# Student Dict
# {1: 'Amit', 2: 'Rahul', 3: 'Priya', 4: 'Sneha'}
#
# After Deleting
# {1: 'Amit', 3: 'Priya', 4: 'Sneha'}
